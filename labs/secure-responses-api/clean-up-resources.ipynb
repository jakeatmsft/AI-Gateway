# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import os, sys
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group = f"lab-{deployment_name}"

utils.cleanup_resources(deployment_name, resource_group_name=resource_group)
# Out:
# 👉🏽 🧹 Cleaning up resource group 'lab-secure-responses-api'...
# ⚙️ Running: az deployment group show --name secure-responses-api -g lab-secure-responses-api -o json
# ✅ Deployment retrieved ⌚ 19:57:17.143369 :11s]
# 👉🏽 Deployment provisioning state: Succeeded
# ⚙️ Running: az resource list -g lab-secure-responses-api --resource-type "microsoft.cognitiveservices/accounts/projects"
# ✅ Retrieved AI Foundry projects ⌚ 19:57:28.703169 :11s]
# 👉🏽 Deleting AI Foundry project 'foundry1-geb7rv5rbxd3o/secure-responses-api-foundry1' in resource group 'lab-secure-responses-api'...
# ⚙️ Running: az resource delete --ids "/subscriptions/6025ba02-1dfd-407f-b358-88f811c7c7aa/resourceGroups/lab-secure-responses-api/providers/Microsoft.CognitiveServices/accounts/foundry1-geb7rv5rbxd3o/projects/secure-responses-api-foundry1"
# ✅ AI Foundry project 'foundry1-geb7rv5rbxd3o/secure-responses-api-foundry1' deleted ⌚ 19:57:52.779584 :24s]
# ⚙️ Running: az cognitiveservices account list -g lab-secure-responses-api
# ✅ Listed CognitiveService accounts ⌚ 19:58:02.826399 :10s]
# 👉🏽 Deleting and purging Cognitive Service Account 'foundry1-geb7rv5rbxd3o' in resource group 'lab-secure-responses-api'...
# ⚙️ Running: az cognitiveservices account delete -g lab-secure-responses-api -n foundry1-geb7rv5rbxd3o
# ✅ Cognitive Services 'foundry1-geb7rv5rbxd3o' deleted ⌚ 19:58:18.608690 :15s]
# ⚙️ Running: az cognitiveservices account purge -g lab-secure-responses-api -n foundry1-geb7rv5rbxd3o -l "swedencentral"
# ✅ Cognitive Services 'foundry1-geb7rv5rbxd3o' purged ⌚ 19:59:27.203586 :8s]
# ⚙️ Running:  az apim list -g lab-secure-responses-api
# ✅ Listed APIM resources ⌚ 19:59:38.316201 :11s]
# 👉🏽 Deleting and purging API Management 'apim-geb7rv5rbxd3o' in resource group 'lab-secure-responses-api'...
# ⚙️ Running: az apim delete -n apim-geb7rv5rbxd3o -g lab-secure-responses-api -y
# ✅ API Management 'apim-geb7rv5rbxd3o' deleted ⌚ 20:01:32.996251 :54s]
# ⚙️ Running: az apim deletedservice purge --service-name apim-geb7rv5rbxd3o --location "West Europe"
# ✅ API Management 'apim-geb7rv5rbxd3o' purged ⌚ 20:03:06.823211 :33s]
# ⚙️ Running: az keyvault list -g lab-secure-responses-api
# ✅ Listed Key Vault resources ⌚ 20:03:15.348575 :8s]
# 👉🏽 🧹 Deleting resource group 'lab-secure-responses-api'... ⌚ 20:03:15.349466
# ⚙️ Running: az group delete --name lab-secure-responses-api -y
# ✅ Resource group 'lab-secure-responses-api' deleted ⌚ 20:04:40.960687 :25s]
# 👉🏽 🧹 Cleanup completed. ⌚ 20:04:40.962670
