# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import os, sys
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
utils.cleanup_resources(deployment_name)
# Out:
# 👉🏽 🧹 Cleaning up resource group 'lab-realtime-audio'...
# ⚙️ Running: az deployment group show --name realtime-audio -g lab-realtime-audio -o json
# ✅ Deployment retrieved ⌚ 10:49:25.591306 :8s]
# 👉🏽 Deployment provisioning state: Succeeded
# ⚙️ Running: az resource list -g lab-realtime-audio --resource-type "microsoft.cognitiveservices/accounts/projects"
# ✅ Retrieved AI Foundry projects ⌚ 10:49:30.508612 :4s]
# 👉🏽 Deleting AI Foundry project 'foundry1-kdu56pasifuk4/realtime-audio-foundry1' in resource group 'lab-realtime-audio'...
# ⚙️ Running: az resource delete --ids "/subscriptions/6025ba02-1dfd-407f-b358-88f811c7c7aa/resourceGroups/lab-realtime-audio/providers/Microsoft.CognitiveServices/accounts/foundry1-kdu56pasifuk4/projects/realtime-audio-foundry1"
# ✅ AI Foundry project 'foundry1-kdu56pasifuk4/realtime-audio-foundry1' deleted ⌚ 10:49:42.586448 :12s]
# ⚙️ Running: az cognitiveservices account list -g lab-realtime-audio
# ✅ Listed CognitiveService accounts ⌚ 10:49:46.477106 :3s]
# 👉🏽 Deleting and purging Cognitive Service Account 'foundry1-kdu56pasifuk4' in resource group 'lab-realtime-audio'...
# ⚙️ Running: az cognitiveservices account delete -g lab-realtime-audio -n foundry1-kdu56pasifuk4
# ✅ Cognitive Services 'foundry1-kdu56pasifuk4' deleted ⌚ 10:49:53.139439 :6s]
# ⚙️ Running: az cognitiveservices account purge -g lab-realtime-audio -n foundry1-kdu56pasifuk4 -l "eastus2"
# ✅ Cognitive Services 'foundry1-kdu56pasifuk4' purged ⌚ 10:50:25.414048 :32s]
# ⚙️ Running:  az apim list -g lab-realtime-audio
# ✅ Listed APIM resources ⌚ 10:50:29.787021 :4s]
# 👉🏽 Deleting and purging API Management 'apim-kdu56pasifuk4' in resource group 'lab-realtime-audio'...
# ⚙️ Running: az apim delete -n apim-kdu56pasifuk4 -g lab-realtime-audio -y
# ✅ API Management 'apim-kdu56pasifuk4' deleted ⌚ 10:51:35.592825 :5s]
# ⚙️ Running: az apim deletedservice purge --service-name apim-kdu56pasifuk4 --location "East US 2"
# ✅ API Management 'apim-kdu56pasifuk4' purged ⌚ 10:53:05.828652 :30s]
# ⚙️ Running: az keyvault list -g lab-realtime-audio
# ✅ Listed Key Vault resources ⌚ 10:53:11.901656 :6s]
# 👉🏽 🧹 Deleting resource group 'lab-realtime-audio'... ⌚ 10:53:11.902644
# ⚙️ Running: az group delete --name lab-realtime-audio -y
# ✅ Resource group 'lab-realtime-audio' deleted ⌚ 10:54:34.881354 :22s]
# 👉🏽 🧹 Cleanup completed. ⌚ 10:54:34.882390
