# %% [markdown]
# # Clean up Microsoft Web IQ lab resources
#
# Delete the resource group created by the Web IQ usage-tracking lab to stop Azure charges. This removes APIM, Application Insights, Log Analytics, the APIM subscriptions, and the secret Web IQ named value. It does not change or delete your Web IQ account or API key.

# %%
import sys

sys.path.insert(1, '../../shared')
import utils

deployment_name = 'web-iq'
resource_group_name = f'lab-{deployment_name}'

utils.cleanup_resources(deployment_name, resource_group_name=resource_group_name)
